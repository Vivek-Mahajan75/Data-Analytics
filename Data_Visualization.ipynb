# %% [markdown]
# # Data Visualization

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x = np.array([2,6,14,19,33,39,41,59,60,76])
y = np.array([10,13,21,22,47,37,58,71,82,88])
z = np.array([67,65,54,49,44,41,30,27,32,17])
p = np.array([45,66,54,26,45,67,44,57,22,47])

# %% [markdown]
# #### Line plot

# %%
plt.plot(x,y)

# %%
plt.plot(x,z)

# %%
plt.plot(x,p)

# %%
plt.title('My first Plot')
plt.xlabel('First Value')
plt.ylabel('second Value')
plt.grid()
plt.xlim(0,90)
plt.ylim(0,90)
plt.xticks(range(0,91,10))
plt.yticks(range(0,91,10))
plt.plot(x,y)

# %%
plt.title('My first Plot')
plt.xlabel('First Value')
plt.ylabel('second Value')
plt.grid()
plt.xlim(0,90)
plt.ylim(0,90)
plt.xticks(range(0,91,10))
plt.yticks(range(0,91,10))
plt.plot(x,y,color = 'b',marker = 'o', ms = 10,mfc=  'red',lw = 2,ls = '-.') # ms = marker size mfc = marker face size

# %%
plt.title('My first Plot')
plt.xlabel('First Value')
plt.ylabel('second Value')
plt.grid()
plt.xlim(0,90)
plt.ylim(0,90)
plt.xticks(range(0,91,10))
plt.yticks(range(0,91,10))
plt.plot(x,y,color= '#07FC12',label = '2022')
plt.plot(x,z,color = '#EF07F6',label = '2023')
plt.plot(x,p,color = '#EFF704',label = '2024')
plt.legend()

# %%
plt.subplot(1,2,1)
plt.title('2022')
plt.xlabel('First Value')
plt.ylabel('second Value')
plt.grid()
plt.xlim(0,90)
plt.ylim(0,90)
plt.xticks(range(0,91,10))
plt.yticks(range(0,91,10))
plt.plot(x,y, color='r')

plt.subplot(1,2,2)
plt.title('2023')
plt.xlabel('First Value')
plt.ylabel('second Value')
plt.grid()
plt.xlim(0,90)
plt.ylim(0,90)
plt.xticks(range(0,91,10))
plt.yticks(range(0,91,10))
plt.plot(x,p, color='g')

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,3,1)
plt.title('2022')
plt.xlabel('First Value')
plt.ylabel('second Value')
plt.grid()
plt.xlim(0,90)
plt.ylim(0,90)
plt.xticks(range(0,91,10))
plt.yticks(range(0,91,10))
plt.plot(x,y, color='r')

plt.subplot(1,3,2)
plt.title('2023')
plt.xlabel('First Value')
plt.ylabel('second Value')
plt.grid()
plt.xlim(0,90)
plt.ylim(0,90)
plt.xticks(range(0,91,10))
plt.yticks(range(0,91,10))
plt.plot(x,z, color='g')

plt.subplot(1,3,3)
plt.title('2024')
plt.xlabel('First Value')
plt.ylabel('second Value')
plt.grid()
plt.xlim(0,90)
plt.ylim(0,90)
plt.xticks(range(0,91,10))
plt.yticks(range(0,91,10))
plt.plot(x,p, color='b')

# %%
plt.subplot(2,2,1)
plt.plot(x,y)

plt.subplot(1,2,2)
plt.plot(x,z)
plt.subplot(2,2,3)
plt.plot(x,p)

# %%
sal = pd.read_csv('Salary_Data.csv')

# %%
plt.plot(sal['YearsExperience'],sal['Salary'],color='g')

# %% [markdown]
# ### SCATTER PLOT

# %%
plt.title('My first Plot')
plt.xlabel('First Value')
plt.ylabel('second Value')
plt.grid()
plt.xlim(0,90)
plt.ylim(0,90)
plt.xticks(range(0,91,10))
plt.yticks(range(0,91,10))
plt.scatter(x,y)

# %%
from sklearn.datasets import load_iris

# %%
iris = load_iris()

# %%
x = iris.data
y = iris.target

# %%
plt.figure(figsize=(16,9))
plt.subplot(2,2,1)
plt.title('Sepal Length vs Sepal Width')
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.scatter(x[:,0],x[:,1],c=y)

plt.subplot(2,2,2)
plt.title('Sepal Width vs Petal Length ')
plt.title('Sepal Width')
plt.xlabel('Sepal Width')
plt.ylabel('Petal Length')
plt.scatter(x[:,1],x[:,2],c=y)

plt.subplot(2,2,3)
plt.title('Petal Length vs Petal Width ')
plt.xlabel('Petal Length')
plt.ylabel('Petal Width')
plt.scatter(x[:,2],x[:,3],c=y)

plt.subplot(2,2,4)
plt.title('Sepal Length vs Petal Length ')
plt.xlabel('Sepal Length')
plt.ylabel('Petal Length')
plt.scatter(x[:,0],x[:,2],c=y)

# %% [markdown]
# ## Bar Plot

# %%
langs = ['C','C++','Java','Python','PHP','JavaScript']
studs = [67,92,104,168,122,150],[45,87,56,105,100,106]

# %%
plt.title('Total Enrollement')
plt.grid()
plt.xlabel('courses')
plt.ylabel('Total Students')
plt.bar(langs,studs[0],width=0.25)
plt.bar(langs,studs[1],width=0.45)
# Out:
# <BarContainer object of 6 artists>

# %%
plt.title('Total Enrollement')
plt.grid()
plt.xlabel('courses')
plt.ylabel('Total Students')
plt.barh(langs,studs[0],color='purple')
# Out:
# <BarContainer object of 6 artists>

# %%
df = pd.read_csv('student.csv')

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
plt.title('students progress')
plt.grid()
plt.xlabel('name')
plt.ylabel('marks')
plt.bar(df['name'],df['marks'],color='skyblue')
# Out:
# <BarContainer object of 10 artists>

# %%
plt.title('students progress')
plt.grid()
plt.xlabel('name')
plt.ylabel('marks')
plt.bar(df['name'],df['marks'],color='skyblue')
plt.bar(df['name'],df['marks'],color='skyblue')
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# ## Pie Chart

# %%
plt.title('% enrollment')
plt.pie(studs[0],labels = langs,autopct= '%2.2f%%',shadow = True,radius = 1.5,explode = (0,0,0.2,0,0,0));

# %%
sna = pd.read_csv('Social_Network_Ads.csv')

# %%
sna
# Out:
#       User ID  Gender   Age  EstimatedSalary  Purchased
# 0    15624510    Male  19.0          19000.0          0
# 1    15810944    Male  35.0          20000.0          0
# 2    15668575  Female  26.0          43000.0          0
# 3    15603246  Female  27.0          57000.0          0
# 4    15804002    Male  19.0          76000.0          0
# ..        ...     ...   ...              ...        ...
# 395  15691863  Female  46.0          41000.0          1
# 396  15706071    Male  51.0          23000.0          1
# 397  15654296  Female  50.0          20000.0          1
# 398  15755018    Male  36.0          33000.0          0
# 399  15594041  Female  49.0          36000.0          1
#
# [400 rows x 5 columns]

# %%
x=sna['Gender'].value_counts()

# %%
x
# Out:
# Gender
# Female    204
# Male      196
# Name: count, dtype: int64

# %%
plt.title('% Gender')
plt.pie(x,labels =sna['Gender'].value_counts().index ,autopct= '%2.2f%%',radius = 1.5,explode = (0, 0.1));

# %% [markdown]
# ## Histogram

# %%
plt.xticks(range(10,61,10))
plt.yticks(range(0,141,10))
plt.grid()
plt.hist(sna['Age'],bins = range(10,61,10), color='pink');

# %%
plt.figure(figsize=(16,9))
plt.subplot(1,2,1)
plt.xticks(range(10,61,10))
plt.yticks(range(0,141,10))
plt.hist(sna['Age'],bins = range(10,61,10), color='peachpuff');

plt.subplot(1,2,2)
plt.xticks(range(10000,150001,15000))
plt.yticks(range(0,141,10))
plt.hist(sna['EstimatedSalary'],bins = range(10000,150001,15000), color='palevioletred');

# %%
### KDE plot

# %%
sns.kdeplot(sna['Age'],color = 'darkcyan')
# Out:
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.displot(sna['EstimatedSalary'],color = 'darkcyan')
# Out:
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(sna['EstimatedSalary'],color = 'mediumpurple',kde=True)
# Out:
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='EstimatedSalary', ylabel='Count'>

# %% [markdown]
# ## Box Plot

# %%
plt.boxplot(sna['Age']);

# %%
iris = sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.boxplot(iris)
# Out:
# <Axes: >

# %%
iris.plot()
# Out:
# <Axes: >

# %%
iris.plot.scatter(x='sepal_length', y='petal_length')
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
sna['Purchased'].value_counts().plot.pie(autopct= '%2.2f%%',explode = (0, 0.1))
# Out:
# <Axes: ylabel='count'>

# %%
df.plot.bar()
# Out:
# <Axes: >

# %%
df.plot.box()
# Out:
# <Axes: >

# %%
tasks = ["Task A","Task B","Task C","Task D"]
start_dates = [0,2,5,8]
durations= [3,4,4,2]

fig, ax = plt.subplots(figsize=(10,6))

ax.set_ylabel("Tasks")
ax.set_yticks(range(len(tasks)))
ax.set_yticklabels(tasks)

ax.invert_yaxis()
ax.set_xlabel("Days")

for i, task in enumerate(tasks):
    start_day = start_dates[i]
    duration = durations[i]
    ax.barh(i, duration, left=start_day,color='orange')
    ax.text(start_day + duration/2,i,task,ha='center',va='center')

ax.set_xlim(min(start_dates) - 1, max(start_dates + durations) + 2)
ax.grid(axis='x',linestyle='--',alpha=0.6)
ax.set_title("Gantt Chart")
ax.set_xticks(range(0,11))
plt.show()

# %% [markdown]
# ## Joint plot

# %%
sns.jointplot(x='Age', y='EstimatedSalary', data=sna, hue='Purchased', palette='flare')
# Out:
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## Pairplot

# %%
sns.pairplot(iris)
# Out:
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
sns.pairplot(iris,hue='species')
# Out:
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...
